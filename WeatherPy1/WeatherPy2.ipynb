# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}&q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = 
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather=requests.get(url+city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kahului
# Processing Record 2 of Set 1 | mendoza
# Processing Record 3 of Set 1 | beloha
# Processing Record 4 of Set 1 | marzuq
# Processing Record 5 of Set 1 | fallon
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | sayyan
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yumen
# Processing Record 10 of Set 1 | jutai
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | camacha
# Processing Record 13 of Set 1 | yanam
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | hambantota
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 1 | faanui
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | namibe
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | bowen
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | mount isa
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | sinnamary
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | taltal
# Processing Record 30 of Set 1 | manaure
# Processing Record 31 of Set 1 | cockburn town
# Processing Record 32 of Set 1 | virginia beach
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | venado tuerto
# Processing Record 35 of Set 1 | bireun
# Processing Record 36 of Set 1 | butembo
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | rwamagana
# Processing Record 39 of Set 1 | chokurdakh
# Processing Record 40 of Set 1 | arawa
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | jishou
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | del rio
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | port macquarie
# Processing Record 47 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | beringovskiy
# Processing Record 50 of Set 1 | narsaq
# Processing Record 0 of Set 2 | mar del plata
# Processing Record 1 of Set 2 | la romana
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | langarud
# Processing Record 4 of Set 2 | shishou
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | tilichiki
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | hailey
# Processing Record 10 of Set 2 | colares
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | jesus carranza
# Processing Record 13 of Set 2 | inuvik
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | mildura
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | ha
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | saldanha
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | impfondo
# Processing Record 27 of Set 2 | kikwit
# Processing Record 28 of Set 2 | rosita
# Processing Record 29 of Set 2 | lodja
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | vilhena
# Processing Record 32 of Set 2 | gazanjyk
# Processing Record 33 of Set 2 | beberibe
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | pedasi
# Processing Record 36 of Set 2 | san andres
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | sangar
# Processing Record 41 of Set 2 | trincomalee
# Processing Record 42 of Set 2 | mackenzie
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | laguna
# Processing Record 45 of Set 2 | cermik
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | yarkovo
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | severo-kurilsk
# Processing Record 0 of Set 3 | provideniya
# Processing Record 1 of Set 3 | najran
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | copperas cove
# Processing Record 4 of Set 3 | hvide sande
# Processing Record 5 of Set 3 | pulaski
# Processing Record 6 of Set 3 | wewak
# Processing Record 7 of Set 3 | hirara
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | matay
# Processing Record 10 of Set 3 | aloleng
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | qaqortoq
# Processing Record 13 of Set 3 | altagracia de orituco
# Processing Record 14 of Set 3 | tura
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | la cruz
# Processing Record 19 of Set 3 | san cristobal
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | kununurra
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | yevlax
# Processing Record 28 of Set 3 | tongren
# Processing Record 29 of Set 3 | bagdarin
# Processing Record 30 of Set 3 | sakakah
# Processing Record 31 of Set 3 | zhigansk
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | gunjur
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | shimoda
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | ruteng
# Processing Record 41 of Set 3 | port blair
# Processing Record 42 of Set 3 | sao mateus do sul
# Processing Record 43 of Set 3 | cam ranh
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 47 of Set 3 | kiruna
# Processing Record 48 of Set 3 | chekalin
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 0 of Set 4 | lagoa
# Processing Record 1 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 4 | okhotsk
# Processing Record 3 of Set 4 | cairns
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | antequera
# Processing Record 7 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | huarmey
# Processing Record 17 of Set 4 | banjar
# Processing Record 18 of Set 4 | ostrovnoy
# Processing Record 19 of Set 4 | hokitika
# Processing Record 20 of Set 4 | shingu
# Processing Record 21 of Set 4 | adrar
# Processing Record 22 of Set 4 | christchurch
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | esna
# Processing Record 25 of Set 4 | saskylakh
# Processing Record 26 of Set 4 | salta
# Processing Record 27 of Set 4 | progreso
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | terrace
# Processing Record 30 of Set 4 | hassleholm
# Processing Record 31 of Set 4 | celestun
# Processing Record 32 of Set 4 | atambua
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | namuac
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | grootfontein
# Processing Record 37 of Set 4 | castro
# Processing Record 38 of Set 4 | pacific grove
# Processing Record 39 of Set 4 | liepaja
# Processing Record 40 of Set 4 | belgrade
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | arroio grande
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | buchanan
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | rivne
# Processing Record 0 of Set 5 | los llanos de aridane
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | ossora
# Processing Record 3 of Set 5 | fulton
# Processing Record 4 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 5 | hopkinsville
# Processing Record 6 of Set 5 | byron bay
# Processing Record 7 of Set 5 | campbell river
# Processing Record 8 of Set 5 | bonfim
# Processing Record 9 of Set 5 | eureka
# Processing Record 10 of Set 5 | tuktoyaktuk
# Processing Record 11 of Set 5 | rajshahi
# Processing Record 12 of Set 5 | bubaque
# Processing Record 13 of Set 5 | rocha
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | beipiao
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | atasu
# Processing Record 18 of Set 5 | tsiroanomandidy
# Processing Record 19 of Set 5 | grand gaube
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | cidreira
# Processing Record 23 of Set 5 | ferme-neuve
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | lundazi
# Processing Record 26 of Set 5 | nome
# Processing Record 27 of Set 5 | tuatapere
# Processing Record 28 of Set 5 | guerande
# Processing Record 29 of Set 5 | port elizabeth
# Processing Record 30 of Set 5 | flin flon
# Processing Record 31 of Set 5 | santa rosa
# Processing Record 32 of Set 5 | baykit
# Processing Record 33 of Set 5 | ahipara
# Processing Record 34 of Set 5 | afareaitu
# Processing Record 35 of Set 5 | nishihara
# Processing Record 36 of Set 5 | boksitogorsk
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | honiara
# Processing Record 39 of Set 5 | farafangana
# Processing Record 40 of Set 5 | tonj
# Processing Record 41 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 43 of Set 5 | taoudenni
# Processing Record 44 of Set 5 | simbahan
# Processing Record 45 of Set 5 | ballina
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | sambava
# Processing Record 48 of Set 5 | khasan
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 0 of Set 6 | chinhoyi
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | poum
# Processing Record 3 of Set 6 | ewa beach
# Processing Record 4 of Set 6 | adeje
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 6 | beyneu
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | muskegon
# Processing Record 11 of Set 6 | fuente de oro
# Processing Record 12 of Set 6 | praya
# Processing Record 13 of Set 6 | sampit
# Processing Record 14 of Set 6 | nkhotakota
# Processing Record 15 of Set 6 | mazamari
# Processing Record 16 of Set 6 | havoysund
# Processing Record 17 of Set 6 | vesoul
# Processing Record 18 of Set 6 | skjervoy
# Processing Record 19 of Set 6 | colotlan
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | lichinga
# Processing Record 22 of Set 6 | uvelskiy
# Processing Record 23 of Set 6 | vestmanna
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | esperance
# Processing Record 26 of Set 6 | manokwari
# Processing Record 27 of Set 6 | teya
# Processing Record 28 of Set 6 | basco
# Processing Record 29 of Set 6 | chacabuco
# Processing Record 30 of Set 6 | sur
# Processing Record 31 of Set 6 | saint-joseph
# Processing Record 32 of Set 6 | marfino
# Processing Record 33 of Set 6 | ranong
# Processing Record 34 of Set 6 | freetown
# Processing Record 35 of Set 6 | lovec
# City not found. Skipping...
# Processing Record 36 of Set 6 | aswan
# Processing Record 37 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 6 | matsanga
# City not found. Skipping...
# Processing Record 39 of Set 6 | yaan
# Processing Record 40 of Set 6 | plettenberg bay
# Processing Record 41 of Set 6 | nhulunbuy
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | collie
# Processing Record 44 of Set 6 | katsuura
# Processing Record 45 of Set 6 | teresina
# Processing Record 46 of Set 6 | comodoro rivadavia
# Processing Record 47 of Set 6 | la asuncion
# Processing Record 48 of Set 6 | ust-tsilma
# Processing Record 49 of Set 6 | dingle
# Processing Record 0 of Set 7 | mpanda
# Processing Record 1 of Set 7 | prince rupert
# Processing Record 2 of Set 7 | srednekolymsk
# Processing Record 3 of Set 7 | richards bay
# Processing Record 4 of Set 7 | san vicente
# Processing Record 5 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 7 | alyangula
# Processing Record 7 of Set 7 | port alfred
# Processing Record 8 of Set 7 | mahibadhoo
# Processing Record 9 of Set 7 | synya
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | ternate
# Processing Record 12 of Set 7 | boo
# Processing Record 13 of Set 7 | georgetown
# Processing Record 14 of Set 7 | deputatskiy
# Processing Record 15 of Set 7 | berlevag
# Processing Record 16 of Set 7 | hurghada
# Processing Record 17 of Set 7 | san quintin
# Processing Record 18 of Set 7 | ishigaki
# Processing Record 19 of Set 7 | alanya
# Processing Record 20 of Set 7 | takoradi
# Processing Record 21 of Set 7 | alugan
# Processing Record 22 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 23 of Set 7 | pouebo
# Processing Record 24 of Set 7 | forestville
# Processing Record 25 of Set 7 | roebourne
# Processing Record 26 of Set 7 | lucapa
# Processing Record 27 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 7 | launceston
# Processing Record 29 of Set 7 | nuuk
# Processing Record 30 of Set 7 | yerofey pavlovich
# Processing Record 31 of Set 7 | aleksandrov gay
# Processing Record 32 of Set 7 | iqaluit
# Processing Record 33 of Set 7 | khandyga
# Processing Record 34 of Set 7 | san luis
# Processing Record 35 of Set 7 | tambura
# Processing Record 36 of Set 7 | cayenne
# Processing Record 37 of Set 7 | riyadh
# Processing Record 38 of Set 7 | high rock
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | san jose
# Processing Record 41 of Set 7 | longyearbyen
# Processing Record 42 of Set 7 | mmathubudukwane
# Processing Record 43 of Set 7 | oranjestad
# Processing Record 44 of Set 7 | fukue
# Processing Record 45 of Set 7 | machachi
# Processing Record 46 of Set 7 | darhan
# Processing Record 47 of Set 7 | sale
# Processing Record 48 of Set 7 | zhuzhou
# Processing Record 49 of Set 7 | maragogi
# Processing Record 0 of Set 8 | kutum
# Processing Record 1 of Set 8 | malakal
# Processing Record 2 of Set 8 | griffith
# Processing Record 3 of Set 8 | fujin
# Processing Record 4 of Set 8 | churapcha
# Processing Record 5 of Set 8 | puerto lempira
# Processing Record 6 of Set 8 | pelym
# Processing Record 7 of Set 8 | shellbrook
# Processing Record 8 of Set 8 | helena
# Processing Record 9 of Set 8 | pinawa
# Processing Record 10 of Set 8 | platanos
# Processing Record 11 of Set 8 | balikpapan
# Processing Record 12 of Set 8 | kavaratti
# Processing Record 13 of Set 8 | ban dung
# Processing Record 14 of Set 8 | vostok
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 17 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 18 of Set 8 | belmonte
# Processing Record 19 of Set 8 | waterloo
# Processing Record 20 of Set 8 | peniche
# Processing Record 21 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 22 of Set 8 | portobelo
# Processing Record 23 of Set 8 | russell
# Processing Record 24 of Set 8 | opuwo
# Processing Record 25 of Set 8 | fairbanks
# Processing Record 26 of Set 8 | acapulco
# Processing Record 27 of Set 8 | porto novo
# Processing Record 28 of Set 8 | venezuela
# Processing Record 29 of Set 8 | muros
# Processing Record 30 of Set 8 | touros
# Processing Record 31 of Set 8 | hovd
# Processing Record 32 of Set 8 | zeya
# Processing Record 33 of Set 8 | the valley
# Processing Record 34 of Set 8 | merritt island
# Processing Record 35 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 8 | tandalti
# Processing Record 37 of Set 8 | kayerkan
# Processing Record 38 of Set 8 | zemio
# Processing Record 39 of Set 8 | saint-pierre
# Processing Record 40 of Set 8 | graaff-reinet
# Processing Record 41 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 8 | nova aurora
# Processing Record 43 of Set 8 | karratha
# Processing Record 44 of Set 8 | portland
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | cadillac
# Processing Record 47 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 48 of Set 8 | faya
# Processing Record 49 of Set 8 | savannah bight
# Processing Record 0 of Set 9 | santa cruz del norte
# Processing Record 1 of Set 9 | bambous virieux
# Processing Record 2 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 9 | karonga
# Processing Record 4 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | nehe
# Processing Record 6 of Set 9 | henties bay
# Processing Record 7 of Set 9 | radomsko
# Processing Record 8 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 9 | libreville
# Processing Record 10 of Set 9 | yarmouth
# Processing Record 11 of Set 9 | ekhabi
# Processing Record 12 of Set 9 | kajaani
# Processing Record 13 of Set 9 | severnoye
# Processing Record 14 of Set 9 | northam
# Processing Record 15 of Set 9 | dombarovskiy
# Processing Record 16 of Set 9 | kaeo
# Processing Record 17 of Set 9 | tukums
# Processing Record 18 of Set 9 | sapa
# Processing Record 19 of Set 9 | grafton
# Processing Record 20 of Set 9 | ormara
# Processing Record 21 of Set 9 | westlock
# Processing Record 22 of Set 9 | sheridan
# Processing Record 23 of Set 9 | dinghai
# Processing Record 24 of Set 9 | vila velha
# Processing Record 25 of Set 9 | eirunepe
# Processing Record 26 of Set 9 | ponnani
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | taksimo
# Processing Record 29 of Set 9 | mattru
# Processing Record 30 of Set 9 | dezhou
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | bar harbor
# Processing Record 33 of Set 9 | iskateley
# Processing Record 34 of Set 9 | port moresby
# Processing Record 35 of Set 9 | kita
# Processing Record 36 of Set 9 | mogadishu
# Processing Record 37 of Set 9 | barsovo
# Processing Record 38 of Set 9 | manjhanpur
# Processing Record 39 of Set 9 | salalah
# Processing Record 40 of Set 9 | port augusta
# Processing Record 41 of Set 9 | zaysan
# Processing Record 42 of Set 9 | guamuchil
# Processing Record 43 of Set 9 | charters towers
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | liverpool
# Processing Record 46 of Set 9 | high level
# Processing Record 47 of Set 9 | keningau
# Processing Record 48 of Set 9 | scarborough
# Processing Record 49 of Set 9 | litovko
# Processing Record 0 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 1 of Set 10 | naples
# Processing Record 2 of Set 10 | taihe
# Processing Record 3 of Set 10 | abdulino
# Processing Record 4 of Set 10 | banda aceh
# Processing Record 5 of Set 10 | sao joao da barra
# Processing Record 6 of Set 10 | ixtapa
# Processing Record 7 of Set 10 | pemangkat
# Processing Record 8 of Set 10 | rio gallegos
# Processing Record 9 of Set 10 | ban nahin
# Processing Record 10 of Set 10 | nizhniy ufaley
# Processing Record 11 of Set 10 | sindor
# Processing Record 12 of Set 10 | abu kamal
# Processing Record 13 of Set 10 | rundu
# Processing Record 14 of Set 10 | olinda
# Processing Record 15 of Set 10 | sano
# Processing Record 16 of Set 10 | haines junction
# Processing Record 17 of Set 10 | juba
# Processing Record 18 of Set 10 | coahuayana
# Processing Record 19 of Set 10 | isangel
# Processing Record 20 of Set 10 | hue
# Processing Record 21 of Set 10 | mercedes
# Processing Record 22 of Set 10 | noumea
# Processing Record 23 of Set 10 | mafeteng
# Processing Record 24 of Set 10 | half moon bay
# Processing Record 25 of Set 10 | markova
# Processing Record 26 of Set 10 | puerto carreno
# Processing Record 27 of Set 10 | buta
# Processing Record 28 of Set 10 | mazagao
# Processing Record 29 of Set 10 | san juan
# Processing Record 30 of Set 10 | pahrump
# Processing Record 31 of Set 10 | hobyo
# Processing Record 32 of Set 10 | verkhnyaya inta
# Processing Record 33 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 10 | lata
# Processing Record 35 of Set 10 | ha tinh
# Processing Record 36 of Set 10 | pisco
# Processing Record 37 of Set 10 | mayo
# Processing Record 38 of Set 10 | hofn
# Processing Record 39 of Set 10 | gushikawa
# Processing Record 40 of Set 10 | salinas
# Processing Record 41 of Set 10 | payakumbuh
# Processing Record 42 of Set 10 | baghdad
# Processing Record 43 of Set 10 | san patricio
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | andenes
# Processing Record 46 of Set 10 | ciudad bolivar
# Processing Record 47 of Set 10 | sao felix do xingu
# Processing Record 48 of Set 10 | turukhansk
# Processing Record 49 of Set 10 | boone
# Processing Record 0 of Set 11 | brownsville
# Processing Record 1 of Set 11 | pizarro
# Processing Record 2 of Set 11 | nichinan
# Processing Record 3 of Set 11 | along
# Processing Record 4 of Set 11 | pandhurna
# Processing Record 5 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 11 | bumba
# Processing Record 7 of Set 11 | novikovo
# Processing Record 8 of Set 11 | anadyr
# Processing Record 9 of Set 11 | moron
# Processing Record 10 of Set 11 | boyabat
# Processing Record 11 of Set 11 | qasigiannguit
# Processing Record 12 of Set 11 | ulcinj
# Processing Record 13 of Set 11 | lerwick
# Processing Record 14 of Set 11 | tanout
# Processing Record 15 of Set 11 | maningrida
# Processing Record 16 of Set 11 | tiznit
# Processing Record 17 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 11 | kilindoni
# Processing Record 19 of Set 11 | kamina
# Processing Record 20 of Set 11 | boende
# Processing Record 21 of Set 11 | west richland
# Processing Record 22 of Set 11 | fereydunshahr
# Processing Record 23 of Set 11 | partizanskoye
# Processing Record 24 of Set 11 | point pedro
# Processing Record 25 of Set 11 | mokhsogollokh
# Processing Record 26 of Set 11 | vardo
# Processing Record 27 of Set 11 | vestmannaeyjar
# Processing Record 28 of Set 11 | hohhot
# Processing Record 29 of Set 11 | bani walid
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | kviteseid
# Processing Record 32 of Set 11 | labuhan
# Processing Record 33 of Set 11 | mersin
# Processing Record 34 of Set 11 | mabay
# Processing Record 35 of Set 11 | jacareacanga
# Processing Record 36 of Set 11 | palmer
# Processing Record 37 of Set 11 | mina
# Processing Record 38 of Set 11 | semirom
# Processing Record 39 of Set 11 | teguise
# Processing Record 40 of Set 11 | natal
# Processing Record 41 of Set 11 | belyy yar
# Processing Record 42 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 11 | gangavalli
# Processing Record 44 of Set 11 | stokmarknes
# Processing Record 45 of Set 11 | husavik
# Processing Record 46 of Set 11 | la reforma
# Processing Record 47 of Set 11 | padang
# Processing Record 48 of Set 11 | swan hill
# Processing Record 49 of Set 11 | aurangabad
# Processing Record 0 of Set 12 | sechura
# Processing Record 1 of Set 12 | boa vista
# Processing Record 2 of Set 12 | kristiansund
# Processing Record 3 of Set 12 | bayeux
# Processing Record 4 of Set 12 | novobirilyussy
# Processing Record 5 of Set 12 | gamba
# Processing Record 6 of Set 12 | usinsk
# Processing Record 7 of Set 12 | abrau-dyurso
# Processing Record 8 of Set 12 | mehriz
# Processing Record 9 of Set 12 | kuragino
# Processing Record 10 of Set 12 | zenica
# Processing Record 11 of Set 12 | la ronge
# Processing Record 12 of Set 12 | te anau
# Processing Record 13 of Set 12 | chifeng
# Processing Record 14 of Set 12 | pokrovsk
# Processing Record 15 of Set 12 | utena
# Processing Record 16 of Set 12 | kattivakkam
# Processing Record 17 of Set 12 | lisburn
# Processing Record 18 of Set 12 | benguela
# Processing Record 19 of Set 12 | kotovsk
# Processing Record 20 of Set 12 | suruc
# Processing Record 21 of Set 12 | dicabisagan
# Processing Record 22 of Set 12 | norfolk
# Processing Record 23 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 24 of Set 12 | tagusao
# Processing Record 25 of Set 12 | awbari
# Processing Record 26 of Set 12 | klaeng
# Processing Record 27 of Set 12 | paragominas
# Processing Record 28 of Set 12 | antropovo
# Processing Record 29 of Set 12 | yeppoon
# Processing Record 30 of Set 12 | ao luk
# City not found. Skipping...
# Processing Record 31 of Set 12 | port hedland
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | makakilo city
# Processing Record 34 of Set 12 | shache
# Processing Record 35 of Set 12 | awjilah
# Processing Record 36 of Set 12 | saint anthony
# Processing Record 37 of Set 12 | boshnyakovo
# Processing Record 38 of Set 12 | sohagpur
# Processing Record 39 of Set 12 | tateyama
# Processing Record 40 of Set 12 | saint cloud
# Processing Record 41 of Set 12 | am timan
# Processing Record 42 of Set 12 | digapahandi
# Processing Record 43 of Set 12 | noshiro
# Processing Record 44 of Set 12 | khandbari
# Processing Record 45 of Set 12 | iranshahr
# Processing Record 46 of Set 12 | sisimiut
# Processing Record 47 of Set 12 | salinopolis
# Processing Record 48 of Set 12 | sibolga
# Processing Record 49 of Set 12 | karakol
# Processing Record 0 of Set 13 | marsabit
# Processing Record 1 of Set 13 | pemberton
# Processing Record 2 of Set 13 | eskisehir
# Processing Record 3 of Set 13 | maceio
# Processing Record 4 of Set 13 | corinto
# Processing Record 5 of Set 13 | valentin gomez farias
# Processing Record 6 of Set 13 | raga
# Processing Record 7 of Set 13 | gilazi
# City not found. Skipping...
# Processing Record 8 of Set 13 | shenzhen
# Processing Record 9 of Set 13 | ferrol
# Processing Record 10 of Set 13 | kosikha
# Processing Record 11 of Set 13 | samarai
# Processing Record 12 of Set 13 | sao filipe
# Processing Record 13 of Set 13 | pilot butte
# Processing Record 14 of Set 13 | sulangan
# Processing Record 15 of Set 13 | ambilobe
# Processing Record 16 of Set 13 | pereira barreto
# Processing Record 17 of Set 13 | japura
# Processing Record 18 of Set 13 | anage
# Processing Record 19 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 13 | vuktyl
# Processing Record 21 of Set 13 | altay
# Processing Record 22 of Set 13 | kidal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  kahului  20.8947 -156.4700     87.82        71          20       19.57
# 1  mendoza -32.8908  -68.8272     87.84        25          15        6.35
# 2   beloha -25.1667   45.0500     68.31        86           0        3.15
# 3   marzuq  14.4000   46.4667     62.44        71          13        2.35
# 4   fallon  39.4735 -118.7774     53.92        35          40        4.61
#
#   Country        Date
# 0      US  1668726718
# 1      AR  1668726542
# 2      MG  1668726718
# 3      YE  1668726719
# 4      US  1668726719

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kahului  20.8947 -156.4700     87.82        71          20
# 1        mendoza -32.8908  -68.8272     87.84        25          15
# 2         beloha -25.1667   45.0500     68.31        86           0
# 3         marzuq  14.4000   46.4667     62.44        71          13
# 4         fallon  39.4735 -118.7774     53.92        35          40
#
#          Wind Speed Country        Date
# City_ID
# 0             19.57      US  1668726718
# 1              6.35      AR  1668726542
# 2              3.15      MG  1668726718
# 3              2.35      YE  1668726719
# 4              4.61      US  1668726719

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data['Lat']
y_values = city_data['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb Cell 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Build scatter plot for latitude vs. temperature
# ----> <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> x_values = city_data['Lat']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> y_values = city_data['Max Temp']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> plt.scatter(x_values,y_values)
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data['Lat']
y_values = city_data['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb Cell 15 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Build the scatter plots for latitude vs. humidity
# ----> <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> x_values = city_data['Lat']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> y_values = city_data['Humidity']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> plt.scatter(x_values,y_values)
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data['Lat']
y_values = city_data['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()



# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb Cell 17 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Build the scatter plots for latitude vs. cloudiness
# ----> <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> x_values = city_data['Lat']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> y_values = city_data['Cloudiness']
#       <a href='vscode-notebook-cell:/Users/taylorshaw/Desktop/DataClass/python-api-challenge/WeatherPy1/WeatherPy2.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> plt.scatter(x_values,y_values)
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
